# %%
from urllib.request import urlopen
import json
import pandas as pd
import requests

# %% [markdown]
# ## Driver

# %%
response = urlopen('https://api.openf1.org/v1/drivers')
data = json.loads(response.read().decode('utf-8'))
driver_df = pd.DataFrame(data)

# %%
driver_df
# Out:
#       driver_number broadcast_name        full_name name_acronym  \
# 0                 1   M VERSTAPPEN   Max VERSTAPPEN          VER
# 1                 2     L SARGEANT   Logan SARGEANT          SAR
# 2                 4       L NORRIS     Lando NORRIS          NOR
# 3                10        P GASLY     Pierre GASLY          GAS
# 4                11        S PEREZ     Sergio PEREZ          PER
# ...             ...            ...              ...          ...
# 4638             55        C SAINZ     Carlos SAINZ          SAI
# 4639             61       J DOOHAN      Jack DOOHAN          DOO
# 4640             63      G RUSSELL   George RUSSELL          RUS
# 4641             77       V BOTTAS  Valtteri BOTTAS          BOT
# 4642             81      O PIASTRI    Oscar PIASTRI          PIA
#
#             team_name team_colour first_name   last_name  \
# 0     Red Bull Racing      3671C6        Max  Verstappen
# 1            Williams      37BEDD      Logan    Sargeant
# ...

# %% [markdown]
# ## Session

# %%
response = urlopen('https://api.openf1.org/v1/sessions')
data = json.loads(response.read().decode('utf-8'))
session_df = pd.DataFrame(data)

# %%
session_df
# Out:
#       meeting_key  session_key  driver_number  i1_speed  i2_speed  st_speed  \
# 0            1252         9662              1     290.0     302.0     289.0
# 1            1252         9662              4     281.0     283.0     293.0
# 2            1252         9662             10     287.0     294.0     306.0
# 3            1252         9662             11     283.0     128.0     305.0
# 4            1252         9662             14     285.0     283.0     291.0
# ...           ...          ...            ...       ...       ...       ...
# 1001         1252         9662              4     295.0     305.0     305.0
# 1002         1252         9662             16     291.0     301.0     313.0
# 1003         1252         9662             44     297.0     326.0     337.0
# 1004         1252         9662             55     294.0     301.0     311.0
# 1005         1252         9662             63     295.0     304.0     315.0
#
# ...

# %% [markdown]
# ## Meetings

# %%
response = urlopen('https://api.openf1.org/v1/meetings')
data = json.loads(response.read().decode('utf-8'))
meetings_df = pd.DataFrame(data)

# %%
meetings_df
# Out:
#                  meeting_name  \
# 0          Pre-Season Testing
# 1          Bahrain Grand Prix
# 2    Saudi Arabian Grand Prix
# 3       Australian Grand Prix
# 4       Azerbaijan Grand Prix
# 5            Miami Grand Prix
# 6           Monaco Grand Prix
# 7          Spanish Grand Prix
# 8         Canadian Grand Prix
# 9         Austrian Grand Prix
# 10         British Grand Prix
# 11       Hungarian Grand Prix
# 12         Belgian Grand Prix
# 13           Dutch Grand Prix
# 14         Italian Grand Prix
# 15       Singapore Grand Prix
# 16        Japanese Grand Prix
# 17           Qatar Grand Prix
# 18   United States Grand Prix
# 19     Mexico City Grand Prix
# 20       São Paulo Grand Prix
# 21       Las Vegas Grand Prix
# 22       Abu Dhabi Grand Prix
# 23         Bahrain Grand Prix
# 24   Saudi Arabian Grand Prix
# 25      Australian Grand Prix
# 26        Japanese Grand Prix
# 27         Chinese Grand Prix
# 28           Miami Grand Prix
# 29  Emilia Romagna Grand Prix
# ...

# %% [markdown]
# ## Stints

# %%
response = urlopen('https://api.openf1.org/v1/stints')
data = json.loads(response.read().decode('utf-8'))
stints_df = pd.DataFrame(data)

# %%
stints_df
# Out:
#        meeting_key  session_key  stint_number  driver_number  lap_start  \
# 0             1140         7763             1            4.0          1
# 1             1140         7763             1           20.0          1
# 2             1140         7763             1            2.0          1
# 3             1140         7763             1           24.0          1
# 4             1140         7763             1           14.0          1
# ...            ...          ...           ...            ...        ...
# 17582         1252         9662             3           81.0         31
# 17583         1252         9662             2           44.0         34
# 17584         1252         9662             3           14.0         36
# 17585         1252         9662             3           24.0         38
# 17586         1252         9662             5           20.0         54
#
#        lap_end compound  tyre_age_at_start
# 0            1   MEDIUM                7.0
# ...

# %% [markdown]
# ## Weather

# %%
response = urlopen('https://api.openf1.org/v1/weather')
data = json.loads(response.read().decode('utf-8'))
weather_df = pd.DataFrame(data)

# %%
weather_df
# Out:
#        air_temperature  humidity  pressure  rainfall  track_temperature  \
# 0                 23.8      26.0    1012.2         0               29.7
# 1                 23.8      26.0    1012.2         0               29.7
# 2                 23.8      27.0    1012.2         0               30.0
# 3                 23.8      27.0    1012.2         0               30.1
# 4                 23.8      27.0    1012.2         0               30.1
# ...                ...       ...       ...       ...                ...
# 24995             25.9      60.0    1018.0         0               29.3
# 24996             25.9      60.0    1018.0         0               29.4
# 24997             25.8      60.0    1018.0         0               29.4
# 24998             25.8      60.0    1018.0         0               29.1
# 24999             25.8      60.0    1018.0         0               29.1
#
#        wind_direction  wind_speed                              date  \
# ...

# %% [markdown]
# ## Pit

# %%
response = urlopen('https://api.openf1.org/v1/pit')
data = json.loads(response.read().decode('utf-8'))
pit_df = pd.DataFrame(data)

# %%
pit_df
# Out:
#        pit_duration lap_number  driver_number  \
# 0              35.3          3             14
# 1              40.8          4             18
# 2             155.2          3             21
# 3             277.0          2              2
# 4              27.6          5             16
# ...             ...        ...            ...
# 12201          32.7         32             81
# 12202          21.6         34             44
# 12203          22.4         37             14
# 12204          28.7         39             24
# 12205          22.0         55             20
#
#                                    date  session_key  meeting_key
# 0      2023-06-02T11:33:46.930000+00:00         9095         1211
# 1      2023-06-02T11:35:42.475000+00:00         9095         1211
# 2      2023-06-02T11:36:30.849000+00:00         9095         1211
# 3      2023-06-02T11:37:01.583000+00:00         9095         1211
# 4      2023-06-02T11:37:14.911000+00:00         9095         1211
# ...

# %% [markdown]
# ## Laps

# %%
session_keys = session_df['session_key'].unique().tolist()

# %%
laps_df = pd.DataFrame()

for session_key in session_keys:
    api_url = f'https://api.openf1.org/v1/laps?session_key={session_key}'

    response = urlopen(api_url)
    data = json.loads(response.read().decode('utf-8'))
    
    session_df = pd.DataFrame(data)

    laps_df = pd.concat([laps_df, session_df], ignore_index=True)

# %%
laps_df
# Out:
#         meeting_key  session_key  driver_number  i1_speed  i2_speed  st_speed  \
# 0              1140         9222              1     200.0     221.0     194.0
# 1              1140         9222              2     220.0     236.0     131.0
# 2              1140         9222              4     202.0     190.0     197.0
# 3              1140         9222             10     206.0     219.0     176.0
# 4              1140         9222             14     227.0     255.0     161.0
# ...             ...          ...            ...       ...       ...       ...
# 125699         1252         9662              4     295.0     305.0     305.0
# 125700         1252         9662             16     291.0     301.0     313.0
# 125701         1252         9662             44     297.0     326.0     337.0
# 125702         1252         9662             55     294.0     301.0     311.0
# 125703         1252         9662             63     295.0     304.0     315.0
#
# ...

# %% [markdown]
# ## Race Control

# %%
response = urlopen('https://api.openf1.org/v1/race_control')
data = json.loads(response.read().decode('utf-8'))
race_control_df = pd.DataFrame(data)

# %%
race_control_df
# Out:
#                             date category           flag   scope  \
# 0      2023-02-23T07:00:00+00:00     Flag          GREEN   Track
# 1      2023-02-23T07:00:00+00:00     Flag          GREEN   Track
# 2      2023-02-23T07:08:43+00:00     Flag            RED   Track
# 3      2023-02-23T07:08:43+00:00     Flag            RED   Track
# 4      2023-02-23T07:25:11+00:00    Other           None    None
# ...                          ...      ...            ...     ...
# 10313  2024-12-08T14:31:30+00:00    Other           None    None
# 10314  2024-12-08T14:47:11+00:00     Flag  DOUBLE YELLOW  Sector
# 10315  2024-12-08T14:49:41+00:00     Flag          CLEAR  Sector
# 10316  2024-12-08T14:51:01+00:00     Flag  DOUBLE YELLOW  Sector
# 10317  2024-12-08T14:51:54+00:00     Flag          CLEAR  Sector
#
#                                                  message  session_key  \
# 0                            GREEN LIGHT - PIT EXIT OPEN         9222
# ...

# %% [markdown]
# ## Convert to CSV

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\souri\Documents\School\Data Integration CS 329E

# %%
# Drivers
file_path = "drivers.csv"  
driver_df.to_csv(file_path, index=False)

# %%
# Sessions
file_path = "sessions.csv"  
session_df.to_csv(file_path, index=False)

# %%
# Meetings
file_path = "meetings.csv"  
meetings_df.to_csv(file_path, index=False)

# %%
# Stints
file_path = "stints.csv"  
stints_df.to_csv(file_path, index=False)

# %%
# Weather
file_path = "weather.csv"  
weather_df.to_csv(file_path, index=False)

# %%
# Pit
file_path = "pit.csv"  
pit_df.to_csv(file_path, index=False)

# %%
# Laps
file_path = "laps.csv"  
laps_df.to_csv(file_path, index=False)

# %%
# Race Control
file_path = "race_control.csv"  
race_control_df.to_csv(file_path, index=False)
